# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=100, n_features=2, centers=2, random_state=0)
y = y.reshape(y.shape[0], 1)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap="summer")
plt.show()

# %%
from linear_model import LinearModel
model = LinearModel(learning_rate=0.1, epochs=100)
W, b, losses = model.fit(X, y)
plt.plot(losses)

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X)

accuracy_score(y, y_pred)
# Out:
# 0.87

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="summer")
plt.scatter(4, 2, c='purple')
plt.scatter(-2, 8, c='red')

x0 = np.linspace(-4, 6, 100)
x1 = (-W[0] * x0 - b) / W[1]
plt.plot(x0, x1)
plt.show()

# %%
predict = np.array([[4, 2], [-2, 8]])
model.predict(predict)[:, 0]
# Out:
# array([ True, False])

# %%
from manim_lr import LinearFunction

scene = LinearFunction(X, y, model.wb_list)
scene.render()
# Out:
# [04/07/25 19:02:15] INFO     Animation 0 : Partial movie file written in                   ]8;id=837279;file:///Users/a.brengard/Library/Caches/pypoetry/virtualenvs/custom-linear-regression-7Vx108ar-py3.10/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=324197;file:///Users/a.brengard/Library/Caches/pypoetry/virtualenvs/custom-linear-regression-7Vx108ar-py3.10/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#588\588]8;;\
#                              '/Users/a.brengard/Desktop/Machine Learning Side
#                              Project/custom-linear-regression/media/videos/1080p60/partial
#                              _movie_files/LinearFunction/3977891868_1200069113_895871435.m
#                              p4'
# ...

# %%
from IPython.display import HTML
import os

video_path = os.path.join("media", "videos", "1080p60", f"{scene.__class__.__name__}.mp4")

video_width = 640
video_height = 360

video = HTML(f'''
    <video width="{video_width}" height="{video_height}" controls loop>
        <source src="{video_path}">
    </video>
''')
display(video)
# Out:
#     <video width="640" height="360" controls loop>
#         <source src="media/videos/1080p60/LinearFunction.mp4">
#     </video>
